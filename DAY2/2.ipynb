# %%
i=1
while i<=100:
    if('7' in str(i)):
        print(i)
    i=i+1
# Out:
# 7
# 17
# 27
# 37
# 47
# 57
# 67
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 87
# 97

# %%
num = 123
rev = 0
while num > 0:
    digit = num % 10
    rev = rev * 10 + digit
    num = num // 10
print(rev)
if(num>rev):
    print("number is greter than reverse")
else:
    print("Reverse is greter than num")
# Out:
# 321
# Reverse is greter than nuym

# %%
num = 9875
while num >=9:
    sum = 0
    while num > 0:
        sum+= num % 10
        num = num // 10
    num = sum
print(num)
# Out:
# 2

# %%
num=12345
eCount=0
oCount=0
while num>0:
    digit=num%10
    if(digit%2==0):
        eCount=eCount+1
    else:
        oCount+=1
    num=num//10
print(eCount)
print(oCount)
# Out:
# 2
# 3

# %%
num=12121
temp=num
rev = 0
while temp > 0:
    digit = temp % 10
    rev = rev * 10 + digit
    temp = temp // 10
if(num==rev):
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# 12121
# Palindrome

# %%
correct_username = "Devesh"
correct_password = "8376"
attempts = 3
while attempts > 0:
    username = input("Enter username: ")
    password = input("Enter password: ")
    if username == correct_username and password == correct_password:
        print("Login successful")
        break
    else:
        attempts -= 1
        print("Incorrect credentials")
        print("Attempts left:", attempts)
if attempts == 0:
    print("Account locked")
# Out:
# Incorrect credentials
# Attempts left: 2
# Login successful

# %%
def main():
    a=20
    return a
print(main())
# Out:
# 20

# %%
def main(num):
    rev = 0
    while num > 0:
        digit = num % 10
        rev = rev * 10 + digit
        num = num // 10
    return rev
main(123)
# Out:
# 321

# %%
def main(num):
    num=12345
    eCount=0
    oCount=0
    while num>0:
        digit=num%10
        if(digit%2==0):
            eCount=eCount+1
        else:
            oCount+=1
        num=num//10
    return eCount,oCount
main(12345)
# Out:
# (2, 3)

# %%
import logging

logging.basicConfig(
    filename="countVowel.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def count_vowels(s: str) -> int:
    """
    Count the number of vowels in a given string.
    Parameters:
        s (str): Input string
    Returns:
        int: Total number of vowels in the string.
    """
    logging.info("Counting vowels in the string")
    vowels = "aeiouAEIOU"
    count = 0
    for ch in s:
        if ch in vowels:
            count += 1

    logging.info(f"Vowel count calculated: {count}")
    return count

s = "programming"
result = count_vowels(s)
print("Vowel count:", result)
# Out:
# Vowel count: 3

# %%
import logging

logging.basicConfig(
    filename="Frequency.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
def char_frequency(s: str) -> dict:
    logging.info("Calculating character frequency")
    freq = {}
    for ch in s:
        if ch in freq:
            freq[ch] += 1
        else:
            freq[ch] = 1

    logging.info(f"Character frequency calculated: {freq}")
    return freq
s = "programming"
result = char_frequency(s)

# %%
import logging

logging.basicConfig(
    filename="secondLargest.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def second_largest(nums: list) -> int:
    """
    Find second largest element in a list.
    Parameters:
        nums (list): List of integers
    Returns:
        int: Second largest element
    """
    logging.info("Finding second largest element")

    largest = float('-inf')
    second_largest = float('-inf')

    for num in nums:
        if num > largest:
            second_largest = largest
            largest = num
        elif num > second_largest and num != largest:
            second_largest = num

    logging.info(f"Largest: {largest}, Second Largest: {second_largest}")
    return second_largest


numbers = [10, 20, 4, 45, 99]
result = second_largest(numbers)

# %%
inp="Python is very very easy Language"
out=[(word.lower(),len(word))for word in inp.split()]
print(out)
# Out:
# [('python', 6), ('is', 2), ('very', 4), ('very', 4), ('easy', 4), ('language', 8)]

# %%
inp="Hai HeLLO"
out={i:ord(i) for i in inp if i.isupper()}
print(out)
# Out:
# {'H': 72, 'L': 76, 'O': 79}
