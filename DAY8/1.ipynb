# %% [markdown]
# #### Exception Handeling

# %%
a=int(input("Enter the VALUE OF a"))
b=int(input("Enter the VALUE OF b"))
c=a/b
print(c)
# Out:
# 2.0

# %%
try:
    a=int(input("Enter the VALUE OF a"))
    b=int(input("Enter the VALUE OF b"))
    c=a/b
    print(c)
except ZeroDivisionError:
    print("Divison by zero not allowed")
except ValueError:
    print("only integer value allowed")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 try:
# ----> 2     a=int(input("Enter the VALUE OF a"))
#       3     b=int(input("Enter the VALUE OF b"))
#       4     c=a/b
#
# File c:\Users\deves\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File c:\Users\deves\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
# ...

# %%
def safe_div():
    try:
        a=int(input("Enter the VALUE OF a"))
        b=int(input("Enter the VALUE OF b"))
        c=a/b
        print(c)
    except ZeroDivisionError:
        print("Divison by zero not allowed")
        safe_div()
    except ValueError:
        print("only integer value allowed")
        safe_div()

# %%
safe_div()
# Out:
# Divison by zero not allowed
# only integer value allowed
# 0.8

# %%
try:
    a=int(input("Enter the VALUE OF a"))
    b=int(input("Enter the VALUE OF b"))
    c=a/b
    print(c)
except Exception:
    print("Exception is Handeled")
# Out:
# Exception is Handeled

# %%
try:
    a=int(input("Enter the VALUE OF a"))
    b=int(input("Enter the VALUE OF b"))
    c=a/b
    print(c)
except Exception as e:
    print("Exception is Handeled,Error:",e)
# Out:
# Exception is Handeled,Error: division by zero

# %%
try:
    a=int(input("Enter the VALUE OF a"))
    b=int(input("Enter the VALUE OF b"))
    c=a/b
    print(c)
except ZeroDivisionError:
    print("Divison by zero not allowed")
except ValueError:
    print("only integer value allowed")
else:
    print("Divisin Successful")
finally:
    print("program execution completed")
# Out:
# Divison by zero not allowed
# program execution completed

# %%
production=int(input("Enter production count"))
if production <0:
    raise ValueError("out of stock")  #raise use dfor customize error
else:
    print("product is avilable")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 production=int(input("Enter production count"))
#       2 if production <0:
# ----> 3     raise ValueError("out of stock")
#       4 else:
#       5     print("product is avilable")
#
# ValueError: out of stock

# %%
class AgeError(Exception):
    pass

age=int(input("Enter Age:"))
if age<18:
    raise AgeError("Age must be 18 or above") #for specific error we have to create a class of that error
else:
    print("Eligible")
# Out:
# Eligible

# %%
#asertion error

s1=input("enter string s1:")
s2=input("enter string s2:")

assert len(s1)==len(s2),"Length is Diffrent"
print("Length is same")
# Out:
# Length is same
