# %%
lst=[1,2,3,4]
lst=[i**2  for i in lst if i%2==0]
print(lst)
# Out:
# [4, 16]

# %%
s= "Python is both scripting and programing language"
words=[i for i in s.split(' ') if i[0] in 'aeiouAEIOU']
print(words)
# Out:
# ['is', 'and']

# %%
ls=[1,2,5,7,1,4,7,7]
ans={i for i in ls if i>5}
print(ans)
# Out:
# {7}

# %%
num={i for i in range(1,50) if i%3==0 and i%5==0}
num
# Out:
# {15, 30, 45}

# %%
dict={i: i**3 for i in range(1,6)}
dict
# Out:
# {1: 1, 2: 8, 3: 27, 4: 64, 5: 125}

# %%
dict={"Devesh":75,"Alok":68,"Aditya":56,"Achal":45}
ans={i:dict[i] for i in dict if dict[i]>60}
print(ans)
# Out:
# {'Devesh': 75, 'Alok': 68}

# %%
sum=lambda a,b,c:a+b+c
sum(1,2,3)
# Out:
# 6

# %%
class Mobile:
    brand="Apple"
    price="null"
m1=Mobile()
m2=Mobile()

# %%
m1.brand="Samsung"
# m1.price
m1.brand
# Out:
# 'Samsung'

# %%
class Bank:
    bank_name="SBI"
    branch="prayagraj"
    ifsc_code="SBIN0001234"
    country="India"
b1=Bank()
b2=Bank()
b3=Bank()

b1.name="Devesh"
b1.age=19
b1.phone=1234567890
b1.pan="ABCDE1234F"

b2.name="Alok"
b2.age=20
b2.phone=1234567891
b2.pan="ABCDE1234G"

b3.name="Aditya"
b3.age=21   
b3.phone=1234567892
b3.pan="ABCDE1234H"

print(b1.bank_name)
print(b1.name)
print(b2.bank_name)
# Out:
# SBI
# Devesh
# SBI

# %%
class Bank:
    bank_name="SBI"
    branch="prayagraj"
    ifsc_code="SBIN0001234"
    country="India"
    def set_details(obj,name,age,phone,pan,balance):
        obj.name=name
        obj.age=age
        obj.phone=phone
        obj.pan=pan
        obj.balance=balance

#creating objects
b1=Bank()
b1.set_details("Devesh",19,1234567890,"ABCDE1234F",100000)
b2=Bank()
b2.set_details("Alok",20,1234567891,"ABCDE1234G",200000)
b3=Bank()
b3.set_details("Aditya",21,1234567892,"ABCDE1234H",300000)

b1.name
# Out:
# 'Devesh'

# %%
class Bank:
    bank_name="SBI"
    branch="prayagraj"
    ifsc_code="SBIN0001234"
    country="India"

    #constructor to initialize the object
    def __init__(self,name,age,phone,pan,balance):
        self.name=name
        self.age=age
        self.phone=phone
        self.pan=pan
        self.balance=balance
        
    
    #print(c1.name)
    # def display(self):
    #     print(self.name,self.phone,self.balance)
    # def change_phone(self,new_phone):
    #     self.phone=new_phone
    #withdraw
    def withdraw(self,balance):
        if self.balance>=balance and balance>0:
            self.balance-=balance
            print(f"Successfully withdrew {balance}. Remaining balance: {self.balance}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")
    def deposit(self,balance):
        if balance>0:
            self.balance+=balance
#creating objects
c1=Bank("Devesh",19,1234567890,"ABCDE1234F",100000)
c2=Bank("Alok",20,1234567891,"ABCDE1234G",200000)
c3=Bank("Aditya",21,1234567892,"ABCDE1234H",300000)
print(c1.name,c1.phone,c1.balance)
c1.withdraw(20000)
# Out:
# Devesh 1234567890 100000
# Successfully withdrew 20000. Remaining balance: 80000

# %%
class Bank:
    #static/class Menbers
    bname="SBI"
    branch="Hyderabad"
    ifsc="SBIN45798"
    helpline="1800-11-2345"

    #constructor(object Members)
    def __init__(self,name,age,phone,pan,balance):
        self.name=name
        self.age=age
        self.phone=phone
        self.pan=pan
        self.balance=balance

    #object method
    def display(self):
        print(self.name,self.phone,self.balance)
    def withdraw(self,balance):
        if self.balance>=balance and balance>0:
            self.balance-=balance
            print(f"Successfully withdrew {balance}. Remaining balance: {self.balance}")
        else:
            print("Insufficient funds or invalid withdrawal amount.")
    def deposit(self,balance):
        if balance>0:
            self.balance+=balance
    @classmethod
    def branch_change(cls,branch):
        cls.branch=branch
#creating objects
c1=Bank("Devesh",19,1234567890,"ABCDE1234F",100000)
c2=Bank("Alok",20,1234567891,"ABCDE1234G",200000)
c3=Bank("Aditya",21,1234567892,"ABCDE1234H",300000)

Bank.branch_change("kolkata")
print(Bank.branch)
print(c2.branch)
# Out:
# kolkata
# kolkata
