# %%
s='     python is a programing lang'

# %%
s.replace(' ','')
# Out:
# 'pythonisaprograminglang'

# %%
ls=[1,2,3,1,2,3,4,5,6]

# %%
ls.sort()
ls.sort(reverse=True)
ls
# Out:
# [6, 5, 4, 3, 3, 2, 2, 1, 1]

# %%
tup=(1,2,3,1,2,3,4,5,6)

# %%
tup.index(1)
# Out:
# 0

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
dict={100:1,200:2,300:3,(1,2):4}

# %%
dict
# Out:
# {100: 1, 200: 2, 300: 3, (1, 2): 4}

# %%
s1=set([1,2,3,1,2,3,4,5,6])

# %%
s1.pop()
# Out:
# 1

# %%
s1.remove(8)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 s1.remove(8)
#
# KeyError: 8

# %%
s1.discard(8)

# %%
s1
# Out:
# {2, 4, 5, 6}

# %%
3 in 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 3 in 5
#
# TypeError: argument of type 'int' is not iterable

# %%
oct(10)
# Out:
# '0o12'

# %%
r=[1,2,3]
s=r
t=[1,2,3]

# %%
s is r
# Out:
# True

# %%
num=15
if num%3==0 and num%5==0:
    print("Divisible by both")
# Out:
# Divisible by both

# %%
age=int(input("enter age:"))
if age>=18 and age<=25:
    print("Eligible for voting")

# %%
num=int(input("enter number"))
if num>=0:
    print("positive")
else:
    print("Negative")
# Out:
# positive

# %%
marks=int(input("enter marks"))
if marks>=90:
    print('A')
elif marks>=75:
    print('B')
elif marks>60:
    print('c')
else:
    print("fail")
# Out:
# fail

# %%
char=input("enter a character")
if char >='a' and char<='z':
    print("Uppercase letter")
elif char >='A' and char<='Z':
    print("Lowercase letter")
elif char>='0' and char<='9':
    print("Digit")
else:
    print("Special character")
# Out:
# Special character

# %%
experince=int(input("enter experience"))
perf_rating=int(input("enter rating"))
if experince>=5:    
    if perf_rating>=4:
        print("Bonus is 20%")
    else:
        print("Bonus is 10%")
else:
    print("No Bonus")
# Out:
# Bonus is 10%

# %%
num=int(input("Enter Number"))
if num>=0:
    if(num%2==0):
        print("Even")
    else:
        print("odd")
else:
    print("Negative number")
# Out:
# Negative number

# %%
PIN=int(input("Enter Your PIN:"))
Withdrawl=int(input("Enter Withdrawl amount:"))

if (PIN==1234):
    if Withdrawl<=10000:
        print("Withdrawl successful")
    else:
        print("Insufficient balance")
else:
    print("Invalid PIN")
