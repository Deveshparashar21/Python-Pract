# %% [markdown]
# # Data Analysis

# %%
import pandas as pd

# %%
lst=[10,20,30,40,50]
for i in range(len(lst)):
    lst[i]+=5
print(lst)
# Out:
# [15, 25, 35, 45, 55]

# %%
s=pd.Series([10,20,30,40,50])
s+=5
print(s)
# Out:
# 0    15
# 1    25
# 2    35
# 3    45
# 4    55
# dtype: int64

# %%
pd.Series([10,20,30,40,50],index=['x','y','z','a','b'])
# Out:
# x    10
# y    20
# z    30
# a    40
# b    50
# dtype: int64

# %%
s=pd.Series({'a':10,'b':20,'c':30,'d':40,'e':50})

# %%
s.values
# Out:
# array([10, 20, 30, 40, 50])

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
#series operations
s.mean()
s.max()
s.min()
# Out:
# 10

# %%
s.std()
# Out:
# 15.811388300841896

# %%
s.value_counts()
# Out:
# 10    1
# 20    1
# 30    1
# 40    1
# 50    1
# Name: count, dtype: int64

# %%
pd.DataFrame({"A":[1,2],"B":[3,4]})
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df=pd.read_csv('WineQT.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.head(-12)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1126            7.5              0.52         0.40             2.2      0.060
# 1127            8.0              0.30         0.63             1.6      0.081
# 1128            6.2              0.70         0.15             5.1      0.076
# 1129            6.8              0.67         0.15             1.8      0.118
# 1130            7.4              0.35         0.33             2.4      0.068
#
# ...

# %%
df.tail(-5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               6.7             0.580         0.08             1.8      0.097
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 386             9.3             0.715         0.24             2.1      0.070
# 566             8.6             0.630         0.17             2.9      0.099
# 374             9.1             0.220         0.24             2.1      0.078
# 1025            7.0             0.590         0.00             1.7      0.052
# 830             7.6             0.360         0.31             1.7      0.079
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 386                   5.0                  20.0  0.99660  3.12       0.59
# 566                  21.0                 119.0  0.99800  3.09       0.52
# 374                   1.0                  28.0  0.99900  3.41       0.87
# 1025                  3.0                   8.0  0.99600  3.41       0.47
# 830                  26.0                  65.0  0.99716  3.46       0.62
#
#       alcohol  quality    Id
# ...

# %%
df.sample(3,ignore_index=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.7              0.52         0.09             2.5      0.091
# 1            7.0              0.54         0.00             2.1      0.079
# 2            8.1              0.82         0.00             4.1      0.095
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 20.0                  49.0  0.99760  3.34       0.86
# 1                 39.0                  55.0  0.99560  3.39       0.84
# 2                  5.0                  14.0  0.99854  3.36       0.53
#
#    alcohol  quality    Id
# 0     10.6        7   288
# 1     11.4        6  1422
# 2      9.6        5  1032

# %%
df.ndim
# Out:
# 2

# %%
df.shape
df.size
# Out:
# 14859

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
#by default it will give only numeric columns details
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
#for getting string columns details
df.describe(include='all')
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.describe(include='int')
# Out:
#            quality           Id
# count  1143.000000  1143.000000
# mean      5.657043   804.969379
# std       0.805824   463.997116
# min       3.000000     0.000000
# 25%       5.000000   411.000000
# 50%       6.000000   794.000000
# 75%       6.000000  1209.500000
# max       8.000000  1597.000000

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Id                        int64
# dtype: object

# %%
df['citric acid'].dtypes
# Out:
# dtype('float64')

# %%
df.select_dtypes(include='int').columns
# Out:
# Index(['quality', 'Id'], dtype='object')

# %%
#Indexing and Selection
df.iloc[0:2,0:4]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar
# 0            7.4              0.70          0.0             1.9
# 1            7.8              0.88          0.0             2.6

# %%
df['fixed acidity'][0]
# Out:
# np.float64(7.4)

# %%
df.iat[0,0]
# Out:
# np.float64(7.4)

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.fillna(df.mean())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
#Duplicate Data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True) #inplac=True will make the changes in the original dataframe

# %%
df.sample(5).sort_index()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 99             8.1             0.670         0.55             1.8      0.117
# 261           10.4             0.575         0.61             2.6      0.076
# 520            9.5             0.550         0.66             2.3      0.387
# 768           11.6             0.410         0.54             1.5      0.095
# 939            6.7             0.460         0.24             1.7      0.077
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 99                  32.0                 141.0  0.99680  3.17       0.62
# 261                 11.0                  24.0  1.00000  3.16       0.69
# 520                 12.0                  37.0  0.99820  3.17       0.67
# 768                 22.0                  41.0  0.99735  3.02       0.76
# 939                 18.0                  34.0  0.99480  3.39       0.60
#
#      alcohol  quality    Id
# 99       9.4        5   145
# ...

# %%
df.sample(5).reset_index(drop=True)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            9.6              0.42         0.35             2.1      0.083
# 1            7.0              0.38         0.49             2.5      0.097
# 2            5.6              0.85         0.05             1.4      0.045
# 3            7.7              0.57         0.21             1.5      0.069
# 4            8.9              0.59         0.50             2.0      0.337
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 17.0                  38.0  0.99622  3.23       0.66
# 1                 33.0                  85.0  0.99620  3.39       0.77
# 2                 12.0                  88.0  0.99240  3.56       0.82
# 3                  4.0                   9.0  0.99458  3.16       0.54
# 4                 27.0                  81.0  0.99640  3.04       1.61
#
#    alcohol  quality    Id
# 0     11.1        6  1153
# 1     11.4        6   527
# ...

# %%
df.sort_values(by='alcohol')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 388            14.3              0.31         0.74             1.8      0.075
# 368            10.4              0.61         0.49             2.1      0.200
# 1023           10.0              0.38         0.38             1.6      0.169
# 263             7.9              0.24         0.40             1.6      0.056
# 1051            9.9              0.50         0.50            13.8      0.205
# ...             ...               ...          ...             ...        ...
# 589             4.9              0.42         0.00             2.1      0.048
# 419             5.0              0.42         0.24             2.0      0.060
# 98              5.2              0.34         0.00             1.8      0.050
# 96              5.2              0.34         0.00             1.8      0.050
# 462            15.9              0.36         0.65             7.5      0.096
#
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
# Id                        -0.275826         -0.007892    -0.139011
#
# ...

# %%
df["quality"].value_counts()
# Out:
# quality
# 5    483
# 6    462
# 7    143
# 4     33
# 8     16
# 3      6
# Name: count, dtype: int64

# %%
df[(df["quality"]>5) & (df["alcohol"]>10)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 12              8.5             0.280         0.56             1.8      0.092
# 26              7.8             0.600         0.14             2.4      0.086
# 30              7.5             0.490         0.20             2.6      0.332
# 38              7.6             0.510         0.15             2.8      0.110
# 48              8.0             0.705         0.05             1.9      0.074
# ...             ...               ...          ...             ...        ...
# 1135            5.8             0.610         0.11             1.8      0.066
# 1136            6.3             0.550         0.15             1.8      0.077
# 1137            5.4             0.740         0.09             1.7      0.089
# 1138            6.3             0.510         0.13             2.3      0.076
# 1141            5.9             0.550         0.10             2.2      0.062
#
# ...

# %%
df.alcohol*1.10
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
def rating(quality):
    if quality>5:
        return "good"
    else:
        return "bad"

# %%
df["quality review"]=df["quality"].apply(rating)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.to_csv("WineQT_edited.csv",index=False)
