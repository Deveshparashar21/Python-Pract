# %%
import pandas as pd

# %%
df=pd.read_csv("tips.csv")

# %%
df.shape
# Out:
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df["total_bill"].sum()
# Out:
# np.float64(4827.77)

# %%
df["tip"].sum()
# Out:
# np.float64(731.5799999999999)

# %%
df["tip"].mean()
# Out:
# np.float64(2.99827868852459)

# %%
df["total_bill"].mean()
# Out:
# np.float64(19.78594262295082)

# %%
df["sex"].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df[df["sex"] == "Female"]["total_bill"].mean()
# Out:
# np.float64(18.056896551724133)

# %%
df[df["sex"] == "Male"]["total_bill"].mean()
# Out:
# np.float64(20.744076433121016)

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df[df["smoker"] == "Yes"]["total_bill"].mean()
# Out:
# np.float64(20.756344086021507)

# %%
df[df["smoker"] == "Yes"]["tip"].mean()
# Out:
# np.float64(3.008709677419355)

# %%
df[df["smoker"] == "No"]["total_bill"].mean()
# Out:
# np.float64(19.18827814569536)

# %%
df[df["smoker"] == "No"]["tip"].mean()
# Out:
# np.float64(2.9918543046357615)

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df["tip_percent"] = (df["tip"] / df["total_bill"]) * 100
df["tip_percent"].mean()
# Out:
# np.float64(16.08025817225047)

# %% [markdown]
# #male come more often compare to female

# %% [markdown]
# #on average male pay more tips compare to female

# %% [markdown]
# #smokers comes in less number compare to non smokers put pay moore bill as well as tips

# %% [markdown]
# #on dinner time more people come

# %% [markdown]
# #on average tip percent is 16
